# %%
import import_ipynb
from search import *
import matplotlib.pyplot as plt
import cv2

original = search('./noCut')
result = search('./board')

for i in original:
    img = cv2.imread(i)
    plt.figure(figsize=(6,5))
    plt.imshow(img)

for j in result:
    img = cv2.imread(j)
    plt.figure(figsize = (6,5))
    plt.imshow(img)
